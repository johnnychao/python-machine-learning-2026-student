# %% [markdown]
# # 每章自主實作模板
#
# 複製本 notebook 後，依照當週章節填入資料、模型、評估與反思。課程不要求繳交，但建議保存到自己的 Google Drive。

# %% [markdown]
# ## 1. 問題目標
#
# - 本章任務屬於 prediction、interpretation、exploration，還是 deployment?
# - 目標變數是什麼？評分指標是什麼？

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 資料檢查
#
# - 欄位、缺失值、目標變數分布
# - train / validation / test 如何切分

# %%
# 在這裡放入資料讀取與基本檢查

# %% [markdown]
# ## 3. 模型流程
#
# - 前處理
# - 模型訓練
# - 驗證與比較

# %%
# 在這裡放入模型訓練與評估

# %% [markdown]
# ## 4. 結果解讀與限制
#
# - 最重要的輸出是什麼？
# - 可能錯在哪裡？
# - 哪些結論不能講成因果？
